# %% [markdown]
# # BlueEdge Text Matching and Duplicate Detection
#
# This notebook documents the experimental workflow for the BlueEdge text matching and duplicate detection project.
#
# The original experiments were developed in Google Colab and later reorganized into modular Python files inside the `src/` folder.
#
# ## Main Pipeline
#
# The project includes:
#
# - Text preprocessing
# - Similarity feature extraction
# - Group-based train/test splitting
# - Machine learning model comparison
# - Cross-validation
# - Ablation study
# - Benchmark comparison against spaCy and TextBlob

# %% [markdown]
# ## Import Project Modules
#
# The main reusable functions are stored in the `src/` directory.

# %%
import pandas as pd

from src.preprocessing import add_normalized_columns
from src.features import add_similarity_features, fit_tfidf_vectorizer, add_tfidf_feature, FEATURE_COLUMNS
from src.train_models import add_split_blocks, group_train_test_split, scale_features, get_default_models, train_models, predict_models
from src.evaluation import evaluate_predictions, get_best_model_name, summarize_model_results

# %% [markdown]
# ## Load Dataset
#
# Place the dataset inside the `data/` folder before running the notebook.

# %%
DATA_PATH = '../data/final_blueedge_dataset.csv'

# df = pd.read_csv(DATA_PATH, encoding='utf-8-sig')
# df.head()

# %% [markdown]
# ## Notes
#
# The dataset is not included in the repository. Update `DATA_PATH` according to the local dataset file name.
#
# For the full original Colab-style experiment, refer to the original script or reproduce the workflow using the modular files in `src/`.
